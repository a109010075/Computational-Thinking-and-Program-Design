# %% [markdown]
# <a href="https://colab.research.google.com/github/a109010075/Computational-Thinking-and-Program-Design/blob/main/%E3%80%8C%E9%82%B1%E6%86%B6%E9%9B%AF_%E6%9C%9F%E6%9C%AB%E5%A0%B1%E5%91%8A_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **分組名單**
#
# 新聞一丙109010075 邱憶雯
#
# 新聞一丙109010036 陳侑廷
#
# 新聞一丙109010072 呂怡葳
#
# 新聞一丙109010054 粘菀瑄

# %% [markdown]
# **專題腳本**
#
# 專題題目：我的娛樂圈歷險
#
# 專題特色：以大家熟知的娛樂圈練習生制度，創建一款聊天機器人。
#
# 劇情大綱：主角被星探小皮挖掘，進入一場明星之路的海選，而周杰倫特別喜歡同公司的舞者蔡依林，在娛樂公司練習時，竟發生一段驚心動魄的經驗⋯⋯

# %% [markdown]
# **分工內容**
#
# 粘菀瑄負責第一部分
#
# 「歡迎來到這裡」到第一次挑選麥克風
#
#
# 呂怡葳負責第二部分
#
# 第一次挑選麥克風(答案一跟二)到要不要在經紀公司打工
#
#
# 邱憶雯負責第三部分
#
# 第一次挑選麥克風(答案三)到回應老闆
#
#
# 陳侑廷負責第四部分
#
# 和老闆道歉到第二次挑選麥克風

# %%
print("歡迎來到這裡")
name = input("請問你的名字是？ ")
print("你好!"+name+"，讓我重新隆重的歡迎你參加這個海選。")
print("我名叫小皮，是一名星探。")
print("這次邀請你，是想讓你透過海選，體驗我一次千載難逢的機會~")
print("你不用擔心!只要按照我的引導，一定可以很順利進行的!!!")
print("但是，如果你在徵選中表現太差，我是會將你淘汰的。")
print("事前說明就到此結束。接著讓我問你一個問題⋯")

answer = input("你願意參加這個海選嗎(YES/NO)： ")
if answer=="YES" or answer=="yes":
    print("太棒了!那我馬上開始教你發聲技巧，請你跟著我。")
    print("首先，把脖子往後伸，並將你的腹部用力")
    print("先練聲，一階一階唱上去。")
    print("練發聲十分辛苦且無趣。")
    print("但是，如果你慢慢體會，慢慢訓練，就會有翻天覆地的變化喔。")
    print("你非常喜歡蔡依林，尤其是她的舞技。這天，你發現她在公司裡的舞蹈室練舞。")
    print("她的舞蹈有點特別，叫「大藝術家」。")
    print("自從發現她以後，只要有空閒時間，你就會去公司裡的舞蹈室偷看她跳舞。")
    goOrNot1 = input("這天下午正好有空。要去舞蹈室瞧瞧嗎（YES/NO:）： ")
else:
    print("於是小皮就說:好吧！我去找其他人⋯")
    print("Game Over...")
    print("Not the good END")
    exit()

if (answer=="YES" or answer=="yes") and (goOrNot1=="YES" or goOrNot1=="yes"):
    print("你走近舞蹈室一看，發現一群亮眼的舞者。舞姿曼妙地練著舞蹈。")
    print("你靠近那些舞者，忍不住跟著一起練習，他們也高興地稱讚你的天賦。")
    print("正當你十分享受時，一名中年男子走向你⋯")
    print("男子問你「你很喜歡蔡依林？」，你點點頭。")
    print("並且向他說明你是一個新進的練習生，來到舞蹈室跟舞者們練習。")
    print("這男子似乎是娛樂公司的老闆。他聽了笑笑地鼓勵你，並說隨時歡迎你過來。")
    print("老闆將我引進了他的辦公室，桌子上擺放著三個普通的麥克風。")
    print("老闆笑著說，你喜歡唱歌吧。挑一個拿來唱吧。")
    print("你伸手將三個麥克風都摸了摸，是剛從德國運來的，上面的封膜都還沒撕。")
    print("你決定跟著直覺，挑走一個⋯")
    choice1 = input("左邊的麥克風[1]中間的麥克風[2]右邊的麥克風[3]： ")

elif (answer=="YES" or answer=="yes") and (goOrNot1=="NO" or goOrNot1=="no"):
    print("你怕打擾到蔡依林，於是決定不去了，回頭繼續練習唱歌。")
    print("正當你十分投入時，一名中年男子走向你⋯")
    print("男子問你「你很喜歡唱歌?」，你點點頭。")
    print("並且向他說明你是一個新進的練習生。")
    print("這男子似乎是娛樂公司的老闆。他聽了笑笑地鼓勵你，並說隨時歡迎你過來。")
    print("老闆將我引進了他的辦公室，桌子上擺放著三個普通的麥克風。")
    print("老闆笑著說，你喜歡唱歌吧。挑一個拿來唱吧！")
    print("你伸手將三個麥克風都摸了摸，是剛從德國運來的，上面的封膜都還沒撕。")
    print("你決定跟著直覺，挑走一個⋯")
    choice1 = input("左邊的麥克風[1]中間的麥克風[2]右邊的麥克風[3]： ")  


if choice1 == '1':
    print("左邊的麥克風[1]沒有聲音！")
    print("但你完全不受影響，直接清唱歌曲，甚至加上了舞蹈。")
    print("老闆笑得合不攏嘴，開玩笑的說你是天生的諧星。")
    print("你因為還有發聲課要練習，就準備離開辦公室了。")
    print("離開辦公室前老闆提出了一個邀請：")
    print("「你要不要來我這邊打工？工作內容就是每週一天陪我唱歌，偶爾跟那些舞者一起練舞。」")
    workOrNot = input("你要答應老闆的邀請，在經紀公司打工嗎(YES/NO)： ")

elif choice1 == '2':
    print("中間的麥克風[2]是有聲音的！")
    print("你拿起麥克風，咿咿呀呀地唱個沒完⋯")
    print("唱完，你挑了一下眉，還一副意猶未盡的樣子。")
    print("老闆就這麼欣喜若狂地看著我把歌唱完。接著他問我..")
    print("「你要不要來我這邊打工？工作內容就是每週一天陪我唱歌，偶爾跟那些舞者一起練舞。」")
    print("「每週我給你十萬美元。」")
    print("天啊！十萬美元！？你驚魂未定，自己是哪來的狗屎運啊。")
    workOrNot = input("你要答應老闆的邀請，在經紀公司打工嗎(YES/NO)： ")

else:
    print("右邊的麥克風[3]沒有聲音！")
    print("你整個人在發抖。甚至緊張地哭了出來，因為你沒想到會發生這種事。")
    print("老闆尷尬地看著你，也安慰你這只是突發狀況，不要放心上。")
    print("而你卻覺得太丟臉，直衝出辦公室。")
    print("Game Over...")
    print("Not the good END")
    exit()

if workOrNot == "YES" or workOrNot == "yes":
    print("你語帶保留地說你很有意願，但你必須先請示父母的意見")
    print("你說回去請示後，第二天再來跟老闆回報。")
    print("老闆笑了笑表示認可。你便離開了經紀公司。")
    print("沒想到你話還沒說完，父母就把你趕出家門。")
    print("父母說你是個五音不全的音癡，要你不要癡心妄想了，你感到十分難受。")
    print("你為了轉達結果，不得不在前往經紀公司一趟。帶著這樣的難受與不安，你就這麼睡著了。")
    print("隔天下午，結束了早上的發聲課後，你帶著忐忑不安的心情來到經紀公司。")
    print("看了看老闆辦公室的門，還有舞蹈教室的漂亮舞者。")
    officeOrDance = input("你是要直接前往辦公室找老闆[OFFICE] 或者先和舞蹈室的舞者聊天[DANCE]： ")
else:
    print("Game Over...")
    print("Not the good END")
    exit()

if officeOrDance == "OFFICE" or officeOrDance == "office":
    print("你決定直接前往辦公室。你敲了敲門，聽到裡面有人應聲，就推開門走了進去。")
    print("看見你來，老闆非常開心。詢問你昨天的結果如何。")
else:
    print("進到了舞蹈教室後，發現舞者們都不在，看來是去演出了呢...")
    print("所以你就往辦公室的方向走去。")
    print("到了辦公室門口，你敲了敲門，聽到裡面有人應聲，就推開門走了進去。")
    print("看見你來，老闆非常開心。詢問你昨天的結果如何。")

print("你非常沮喪地轉述了前一天詢問的結果，並鄭重地向老闆道了歉。")
print("老闆顯得有些難過，說他早就料想到了")
print("這時你將視線放到了辦公桌的三個麥克風。")
print("老闆似乎是注意到你的眼神，讓你再挑一個麥克風唱。")
print("你伸手摸了摸只有右邊那個是舊的，其他兩個都和上次一樣還未拆封。")
print("老闆笑呵呵地說「不用挑了，音質都是一樣好的。」")
          
choice2 = input("左邊的麥克風 [1] 中間麥克風 [2] 右邊的麥克風 [3]： ")
if choice2 == '1':
    print("你再拿起麥克風咿咿呀呀地唱完蔡依林的歌曲。")
    print("突然你整臉發燙。你甚至緊張地哭了出來，因為你挑到的麥克風沒聲音")
    print("你看見你的老闆火冒三丈地說。")
    print("「你真的是癩蝦蟆想吃天鵝肉，不自量力。麥克風沒聲音就哭哭啼啼的。」")
    print("最後你被趕出經紀公司")
    print("Game Over...")
    print("Not the good END")
            
elif choice2 == '2':
    print("你再次拿起麥克風咿咿呀呀地唱完蔡依林的歌曲。")
    print("你把每個高音都詮釋得非常到位，充滿自信的完成了表演。")
    print("你看見老闆笑容滿面地說。")
    print("「你果然是一個可遇不可求的人才，我會再去找你父母商談的。」")
    print("最後你拿著經紀公司的合約書，離開辦公室。")
    print("Game Over！！！")
    print("Good END ！！！")

else:
    print("你再拿起麥克風咿咿呀呀地唱完蔡依林的歌曲。")
    print("你因為麥克風漏電，而表演得七零八落")
    print("你看見老闆不耐煩地說。")
    print("「表演中途就算有失誤也要裝鎮定，你這樣的表現太令我失望了。」")
    print("最後你眼眶泛淚，十分懊惱地離開辦公室。")
    print("Game Over...")
    print("Not the good END")
# Out:
# 歡迎來到這裡

# %% [markdown]
# 執行結果1：你願意參加這個海選嗎(YES/NO)
#
# 回答yes：接太棒了!那我馬上開始教你發聲技巧，請你跟著我。
#
# 回答no：接於是小皮就說:好吧！我去找其他人⋯ game over
#
# 執行結果2：這天下午正好有空。要去舞蹈室瞧瞧嗎（YES/NO:）
#
# 回答yes：你走近舞蹈室一看，發現一群亮眼的舞者。舞姿曼妙地練著舞蹈。
#
# 回答no：你怕打擾到蔡依林，於是決定不去了，回頭繼續練習唱歌。
#
# 執行結果3：左邊的麥克風[1]中間的麥克風[2]右邊的麥克風[3]：
#
# 回答1：左邊的麥克風[1]沒有聲音！但表現好
#
# 回答2：中間的麥克風[2]是有聲音的！
#
# 回答3：右邊的麥克風[3]沒有聲音！ 表現不好 game over
#
# 執行結果4：你要答應老闆的邀請，在經紀公司打工嗎(YES/NO)
#
# 回答yes：你語帶保留地說你很有意願，但你必須先請示父母的意見
#
# 回答no：game over
#
# 執行結果5：你是要直接前往辦公室找老闆[OFFICE] 或者先和舞蹈室的舞者聊天[DANCE]：
#
# 回答office:你決定直接前往辦公室。你敲了敲門，聽到裡面有人應聲，就推開門走了進去。
#
# 回答dance：進到了舞蹈教室後，發現舞者們都不在，看來是去演出了呢...於是去辦公室
#
# 執行結果6：左邊的麥克風 [1] 中間麥克風 [2] 右邊的麥克風 [3]
#
# 回答1：bad end
#
# 回答2：good end
#
# 回答3：bad end
